# %%
import torch

# %% [markdown]
# ### Tensors

# %%
# scalar
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
py_int = scalar.item()

# %%
py_int
# Out:
# 7

# %%
vector = torch.tensor([7,7] )
vector
# Out:
# tensor([7, 7])

# %%
vector.ndim
vector.shape
# Out:
# torch.Size([2])

# %%
MATRIX = torch.tensor([[1,2], 
                       [3,4],
                       [5,6]])

# %%
MATRIX.ndim
# Out:
# 2

# %% [markdown]
# ### Random tensors

# %%
rand_tensor = torch.rand(4,4,2,2,5)
rand_tensor
# Out:
# tensor([[[[[0.1857, 0.6124, 0.5257, 0.1612, 0.5456],
#            [0.0946, 0.1997, 0.6902, 0.8585, 0.4683]],
#
#           [[0.1659, 0.0178, 0.9811, 0.6427, 0.7404],
#            [0.7649, 0.9230, 0.6136, 0.0841, 0.9682]]],
#
#
#          [[[0.1049, 0.0124, 0.7361, 0.9385, 0.1825],
#            [0.6853, 0.1240, 0.4151, 0.6695, 0.4561]],
#
#           [[0.6105, 0.7889, 0.3845, 0.9619, 0.0222],
#            [0.1552, 0.9328, 0.3191, 0.3769, 0.5260]]],
#
#
#          [[[0.5068, 0.1134, 0.2712, 0.7462, 0.5456],
#            [0.9475, 0.2871, 0.1122, 0.4941, 0.9104]],
#
#           [[0.5346, 0.0686, 0.1810, 0.8437, 0.0056],
#            [0.4761, 0.0105, 0.1333, 0.2767, 0.2077]]],
#
#
#          [[[0.3745, 0.0223, 0.2618, 0.8928, 0.8266],
#            [0.3893, 0.8098, 0.0731, 0.5080, 0.9218]],
#
#           [[0.3984, 0.0612, 0.0732, 0.6866, 0.3199],
#            [0.7242, 0.6141, 0.4232, 0.3452, 0.7377]]]],
#
#
#
#         [[[[0.2149, 0.0149, 0.0196, 0.6872, 0.6667],
# ...
