# %% [markdown]
# ### Preprocessing: Standartization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm
import sklearn.datasets
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### BElow Just samples how to use imputers

# %%
#from sklearn.impute import SimpleImputer
#imputer = SimpleImputer(strategy='median')
#X = imputer.fit_transform(X)
#from sklearn.impute import KNNImputer
#imputer = KNNImputer(n_neighbors=5)
#X = imputer.fit_transform(X)

# %%
data =  sklearn.datasets.load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
df.sample(5)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 110        9.777         16.99           62.50      290.2          0.10370
# 329       16.260         21.88          107.50      826.8          0.11650
# 420       11.570         19.04           74.20      409.7          0.08546
# 346       12.060         18.90           76.66      445.3          0.08386
# 417       15.500         21.08          102.90      803.1          0.11200
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 110           0.08404         0.04334             0.017780         0.1584
# 329           0.12830         0.17990             0.079810         0.1869
# 420           0.07722         0.05485             0.014280         0.2031
# 346           0.05794         0.00751             0.008488         0.1555
# 417           0.15710         0.15220             0.084810         0.2085
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %%
X = df
Y = data.target

# %% [markdown]
# ### Splitting the data into training data and test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %% [markdown]
# ### Standalize the data

# %%
print(data.data.std())
# Out:
# 228.29740508276657

# %%
scalar = StandardScaler()
# .fit calculates the mean and std deviation of the data    
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_standart = scalar.transform(X_train)
# .transform applies the transformation to the data

# %% [markdown]
# ### Label encoding

# %%
cancer_data = pd.read_csv('/Users/alt/Library/CloudStorage/OneDrive-Personal/datas/data.csv')
iris_data = pd.read_csv('/Users/alt/Library/CloudStorage/OneDrive-Personal/datas/iris_data.csv')

# %%
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(cancer_data['diagnosis'])
cancer_data['diagnosis'] = labels

# %%
cancer_data.sample(5)
# Out:
#           id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 85   8612399          1        18.46         18.52          121.10     1075.0
# 373   901288          1        20.64         17.35          134.80     1335.0
# 125    86561          0        13.85         17.21           88.44      588.7
# 446  9110732          1        17.75         28.03          117.30      981.6
# 30    853401          1        18.63         25.11          124.80     1088.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 85           0.09874           0.10530          0.1335              0.08795
# 373          0.09446           0.10760          0.1527              0.08941
# 125          0.08785           0.06136          0.0142              0.01141
# 446          0.09997           0.13140          0.1698              0.08293
# 30           0.10640           0.18870          0.2319              0.12440
#
# ...

# %%
iris_data.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 141  142            6.9           3.1            5.1           2.3
# 139  140            6.9           3.1            5.4           2.1
# 61    62            5.9           3.0            4.2           1.5
# 115  116            6.4           3.2            5.3           2.3
#
#              Species
# 131   Iris-virginica
# 141   Iris-virginica
# 139   Iris-virginica
# 61   Iris-versicolor
# 115   Iris-virginica

# %%
iris_labes = label_encoder.fit_transform(iris_data['Species'])

# %%
iris_data['Species'] = iris_labes

# %% [markdown]
# ### trein split split

# %%
diabetes = pd.read_csv('/Users/alt/Library/CloudStorage/OneDrive-Personal/datas/diabetes.csv')
diabetes.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 531            0      107             76              0        0  45.3
# 540            8      100             74             40      215  39.4
# 508            2       84             50             23       76  30.4
# 80             3      113             44             13        0  22.4
# 22             7      196             90              0        0  39.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 531                     0.686   24        0
# 540                     0.661   43        1
# 508                     0.968   21        0
# 80                      0.140   22        0
# 22                      0.451   41        1

# %%
X = diabetes.drop(columns='Outcome', axis=1)
Y = diabetes['Outcome']

# %%
Y.sample(5)
# Out:
# 133    0
# 620    0
# 370    1
# 713    0
# 329    0
# Name: Outcome, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %% [markdown]
# ### Handle imbalanced Dataset

# %%
credit_data = pd.read_csv('/Users/alt/Library/CloudStorage/OneDrive-Personal/datas/credit_data.csv')
credit_data.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 248099  153792.0 -1.334624 -0.086089 -0.001056 -3.003705  0.890793  4.346254
# 150457   93389.0 -1.925274  1.381783  0.271943 -0.393729 -0.237776  0.619324
# 168312  119163.0 -2.007834 -2.397545  0.151089 -1.789639 -2.432229  1.374348
# 215022  139908.0  1.963638 -0.539131 -0.383647  0.012776 -0.565195  0.120579
# 51300    44881.0  0.876975 -1.549812  1.049853 -0.205660 -1.672734  0.453990
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 248099 -1.976740  2.122501 -0.204931  ...  0.329258  0.645251 -0.059702
# 150457  1.799729 -0.403091  2.820612  ... -0.857255 -0.889709  0.019575
# 168312  4.034681 -0.399985 -0.018849  ...  0.488210 -0.232066  2.295675
# 215022 -0.834841  0.209367  1.286451  ...  0.225416  0.842078  0.179448
# 51300  -1.091391  0.316945  0.234841  ...  0.179065  0.297882 -0.041391
#
# ...

# %%
credit_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
legit = credit_data[credit_data.Class == 0]
fraud = credit_data[credit_data.Class == 1]

# %% [markdown]
# #### Undersampling

# %%
legit = legit.sample(fraud.shape[0]) # to make the data balanced
l_f_data = pd.concat([legit, fraud], axis=0, ignore_index=True)

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ### TF IDF (term frequency and Inverse document frequency)

# %%
import re
from nltk.corpus import stopwords # to remove the stopwords
from nltk.stem import PorterStemmer # to stem the words
import nltk # to remove the punctuation

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/alt/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
text_data = pd.read_csv('/Users/alt/Library/CloudStorage/OneDrive-Personal/datas/train.csv')
text_data.sample(5)
# Out:
#           id                                              title  \
# 5073    5073  CNN Technicians Rush To Empty Wolf Blitzer’s U...
# 7254    7254                                                NaN
# 11741  11741                                                NaN
# 8210    8210  Zakharova: The US is protecting Al-Nusra from ...
# 20431  20431                                        The Mothers
#
#                                      author  \
# 5073                                    NaN
# 7254                             Ideas Time
# 11741                               Rainman
# 8210   Jafe Arnoldski (noreply@blogger.com)
# 20431                               stclair
#
#                                                     text  label
# 5073   CNN Technicians Rush To Empty Wolf Blitzer’s U...      1
# 7254   We are already seeing signs of massive fraud, ...      1
# 11741  Chipotle.coli Mexican Grill weighing on restau...      1
# ...

# %%
text_data = text_data.fillna('')
text_data['content'] = text_data['title'] + ' ' + text_data['author'] + ' ' + text_data['text']

# %%
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

def fast_stemming(text):
    words = re.sub('[^a-zA-Z]', ' ', text).lower().split()
    words = [stemmer.stem(word) for word in words if word not in stop_words]
    return ' '.join(words)

# Apply on the entire column
text_data['content'] = text_data['content'].map(fast_stemming)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 10
#       7     return ' '.join(words)
#       9 # Apply on the entire column
# ---> 10 text_data['content'] = text_data['content'].map(fast_stemming)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# -> 4700     new_values = self._map_values(arg, na_action=na_action)
#    4701     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702         self, method="map"
#    4703     )
#
# ...

# %%
vectorazer = TfidfVectorizer()
X = text_data['content'].values
Y = text_data['label'].values

# %%
vectorazed_data = vectorazer.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 vectorazed_data = vectorazer.fit_transform(X)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:2138, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2131 self._check_params()
#    2132 self._tfidf = TfidfTransformer(
#    2133     norm=self.norm,
#    2134     use_idf=self.use_idf,
#    2135     smooth_idf=self.smooth_idf,
#    2136     sublinear_tf=self.sublinear_tf,
#    2137 )
# -> 2138 X = super().fit_transform(raw_documents)
#    2139 self._tfidf.fit(X)
#    2140 # X is already a transformed view of raw_documents so
#    2141 # we set copy to False
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
# ...
